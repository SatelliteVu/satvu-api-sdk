# %% [markdown]
# # Testing Wallet API SDK

# %%
# Testing the OTM API SDK
from satvu_api_sdk.sdk import SatVuSDK
import os

sdk = SatVuSDK(
    client_id=os.getenv("SV_CLIENT_ID"),
    client_secret=os.getenv("SV_CLIENT_SECRET"),
    env="qa",
)
contract_id = ""

# %% [markdown]
# ## Get Credit Balance

# %%
sdk.wallet.get_credit(contract_id)
